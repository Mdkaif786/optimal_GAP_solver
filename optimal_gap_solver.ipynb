# %%
pip install pulp
# Out:
# Requirement already satisfied: pulp in c:\users\md kaif\anaconda3\lib\site-packages (2.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# optimal method using pulp library

# %%
import os
import pulp

def read_gap_instances(file_path):
    with open(file_path, "r") as file:
        lines = [line.strip() for line in file.readlines() if line.strip()]
    
    index = 0
    num_instances = int(lines[index])
    index += 1

    def read_matrix(rows, cols):
        nonlocal index
        matrix = []
        while len(matrix) < rows:
            row_values = []
            while len(row_values) < cols:
                row_values.extend(map(int, lines[index].split()))
                index += 1
            matrix.append(row_values[:cols])
        return matrix

    instances = []
    for _ in range(num_instances):
        num_servers, num_users = map(int, lines[index].split())
        index += 1

        utility = read_matrix(num_servers, num_users)
        vm_allocation = read_matrix(num_servers, num_users)
        server_capacity = list(map(int, lines[index].split()))
        index += 1

        instances.append((utility, vm_allocation, server_capacity))
    
    return instances

def solve_gap_optimally(utility, vm_allocation, server_capacity, instance_id, file_name):
    num_servers = len(utility)
    num_users = len(utility[0])

    problem = pulp.LpProblem(f"GAP_Instance_{instance_id}_from_{file_name}", pulp.LpMaximize)

    # Binary Decision Variables
    x = [[pulp.LpVariable(f"x_{i}_{j}_{instance_id}", cat='Binary') for j in range(num_users)] for i in range(num_servers)]

    # Objective Function
    problem += pulp.lpSum(utility[i][j] * x[i][j] for i in range(num_servers) for j in range(num_users))

    # Constraints
    for j in range(num_users):
        problem += pulp.lpSum(x[i][j] for i in range(num_servers)) == 1

    for i in range(num_servers):
        problem += pulp.lpSum(vm_allocation[i][j] * x[i][j] for j in range(num_users)) <= server_capacity[i]

    problem.solve()

    # Prepare output
    assignments = [-1] * num_users
    for i in range(num_servers):
        for j in range(num_users):
            if pulp.value(x[i][j]) == 1:
                assignments[j] = i

    total_utility = pulp.value(problem.objective)

    # Output
    print(f"\nProcessing Instance {instance_id} from {file_name}")
    print(f"Task Assignments: {assignments}")
    print(f"Total Optimal Utility: {total_utility}")

if __name__ == "__main__":
    folder_path = r"C:\Users\MD KAIF\Desktop\lab_assignments\ec_lab\gap_dataset_files"
    file_names = [f for f in os.listdir(folder_path) if f.endswith('.txt')]
    file_names.sort(key=lambda f: int(f.split('gap')[1].split('.txt')[0]))  # Ensure proper order: gap1, gap2...

    for file_name in file_names:
        file_path = os.path.join(folder_path, file_name)
        instances = read_gap_instances(file_path)

        for instance_id, (utility, vm_allocation, server_capacity) in enumerate(instances, start=1):
            solve_gap_optimally(utility, vm_allocation, server_capacity, instance_id, file_name)
# Out:
# Processing Instance 1 from gap1.txt
# Task Assignments: [1, 1, 3, 2, 0, 4, 0, 1, 0, 3, 3, 3, 0, 4, 2]
# Total Optimal Utility: 336.0
#
# Processing Instance 2 from gap1.txt
# Task Assignments: [3, 0, 0, 2, 2, 0, 2, 1, 3, 1, 2, 1, 3, 4, 4]
# Total Optimal Utility: 327.0
#
# Processing Instance 3 from gap1.txt
# Task Assignments: [1, 4, 4, 3, 2, 3, 4, 0, 1, 1, 2, 0, 0, 3, 0]
# Total Optimal Utility: 339.0
#
# Processing Instance 4 from gap1.txt
# Task Assignments: [2, 4, 1, 4, 0, 0, 4, 1, 0, 3, 2, 2, 3, 4, 1]
# Total Optimal Utility: 341.0
#
# Processing Instance 5 from gap1.txt
# Task Assignments: [1, 3, 0, 3, 4, 1, 4, 3, 2, 2, 0, 1, 0, 4, 4]
# Total Optimal Utility: 326.0
#
# Processing Instance 1 from gap2.txt
# Task Assignments: [2, 4, 0, 3, 2, 0, 1, 3, 0, 1, 4, 4, 2, 4, 3, 1, 2, 3, 1, 0]
# Total Optimal Utility: 434.0
#
# Processing Instance 2 from gap2.txt
# Task Assignments: [4, 2, 4, 3, 0, 2, 0, 3, 2, 1, 1, 1, 1, 4, 4, 3, 3, 3, 2, 0]
# Total Optimal Utility: 436.0
#
# Processing Instance 3 from gap2.txt
# Task Assignments: [3, 4, 0, 2, 1, 1, 1, 1, 4, 0, 2, 3, 3, 3, 0, 4, 2, 0, 0, 4]
# Total Optimal Utility: 420.0
#
# Processing Instance 4 from gap2.txt
# Task Assignments: [1, 1, 1, 3, 1, 3, 3, 2, 0, 0, 4, 0, 4, 4, 4, 2, 3, 2, 3, 1]
# Total Optimal Utility: 419.0
#
# Processing Instance 5 from gap2.txt
# Task Assignments: [1, 0, 0, 2, 4, 1, 2, 2, 2, 0, 1, 3, 3, 3, 4, 3, 4, 1, 3, 0]
# Total Optimal Utility: 428.0
#
# Processing Instance 1 from gap3.txt
# Task Assignments: [4, 2, 3, 3, 0, 4, 2, 0, 2, 1, 1, 4, 0, 3, 0, 3, 4, 2, 3, 1, 4, 3, 0, 2, 4]
# Total Optimal Utility: 580.0
#
# Processing Instance 2 from gap3.txt
# Task Assignments: [2, 1, 2, 3, 1, 2, 1, 3, 1, 4, 0, 4, 2, 4, 0, 0, 0, 0, 2, 3, 4, 3, 0, 4, 3]
# Total Optimal Utility: 564.0
#
# Processing Instance 3 from gap3.txt
# Task Assignments: [3, 1, 1, 4, 0, 2, 2, 1, 4, 2, 3, 3, 2, 0, 1, 4, 3, 4, 4, 3, 1, 2, 1, 0, 0]
# Total Optimal Utility: 573.0
#
# Processing Instance 4 from gap3.txt
# Task Assignments: [1, 2, 4, 3, 2, 3, 2, 1, 3, 4, 1, 0, 0, 3, 2, 0, 4, 4, 3, 1, 0, 3, 2, 0, 2]
# Total Optimal Utility: 570.0
#
# Processing Instance 5 from gap3.txt
# Task Assignments: [0, 3, 1, 4, 4, 3, 4, 1, 4, 2, 1, 0, 1, 2, 3, 0, 2, 4, 1, 0, 4, 1, 3, 2, 2]
# Total Optimal Utility: 564.0
#
# Processing Instance 1 from gap4.txt
# Task Assignments: [2, 1, 4, 4, 1, 3, 0, 2, 0, 3, 1, 4, 1, 3, 0, 1, 1, 2, 2, 0, 4, 3, 3, 2, 3, 4, 2, 0, 1, 4]
# Total Optimal Utility: 656.0
#
# Processing Instance 2 from gap4.txt
# Task Assignments: [2, 2, 4, 0, 1, 0, 2, 0, 3, 1, 2, 1, 0, 3, 4, 4, 1, 3, 4, 2, 3, 4, 2, 3, 1, 0, 3, 0, 4, 1]
# Total Optimal Utility: 644.0
#
# Processing Instance 3 from gap4.txt
# Task Assignments: [4, 0, 1, 0, 4, 4, 3, 1, 0, 3, 2, 3, 0, 1, 4, 4, 4, 2, 3, 3, 3, 2, 2, 2, 0, 2, 1, 4, 4, 1]
# Total Optimal Utility: 673.0
#
# Processing Instance 4 from gap4.txt
# Task Assignments: [4, 1, 1, 3, 2, 1, 2, 3, 2, 1, 4, 2, 0, 4, 3, 0, 1, 4, 0, 4, 0, 4, 4, 3, 3, 0, 1, 2, 3, 0]
# Total Optimal Utility: 647.0
#
# Processing Instance 5 from gap4.txt
# Task Assignments: [4, 2, 4, 3, 0, 1, 1, 0, 1, 2, 4, 1, 4, 2, 1, 3, 2, 4, 0, 3, 3, 3, 4, 1, 2, 0, 0, 0, 0, 3]
# Total Optimal Utility: 664.0
#
# Processing Instance 1 from gap5.txt
# Task Assignments: [0, 0, 5, 3, 4, 1, 3, 7, 2, 5, 1, 6, 7, 6, 4, 5, 4, 1, 6, 5, 0, 3, 4, 2]
# Total Optimal Utility: 563.0
#
# Processing Instance 2 from gap5.txt
# Task Assignments: [5, 3, 5, 7, 3, 4, 2, 1, 7, 2, 0, 4, 5, 6, 4, 0, 6, 0, 6, 7, 1, 3, 3, 1]
# Total Optimal Utility: 558.0
#
# Processing Instance 3 from gap5.txt
# Task Assignments: [3, 4, 4, 4, 0, 6, 4, 6, 5, 0, 0, 6, 1, 5, 1, 2, 5, 3, 7, 2, 2, 7, 5, 4]
# Total Optimal Utility: 564.0
#
# Processing Instance 4 from gap5.txt
# Task Assignments: [6, 3, 2, 4, 3, 0, 6, 3, 0, 2, 5, 5, 7, 1, 2, 4, 2, 6, 4, 0, 0, 5, 7, 1]
# Total Optimal Utility: 568.0
#
# Processing Instance 5 from gap5.txt
# Task Assignments: [2, 6, 5, 1, 6, 1, 6, 4, 1, 2, 3, 2, 0, 3, 2, 5, 0, 7, 0, 7, 7, 4, 4, 5]
# Total Optimal Utility: 559.0
#
# Processing Instance 1 from gap6.txt
# Task Assignments: [0, 6, 6, 4, 3, 0, 1, 2, 7, 7, 7, 7, 5, 4, 0, 1, 0, 6, 1, 1, 7, 4, 1, 5, 4, 5, 2, 5, 5, 2, 3, 3]
# Total Optimal Utility: 761.0
#
# Processing Instance 2 from gap6.txt
# Task Assignments: [4, 1, 7, 2, 5, 2, 0, 6, 1, 5, 4, 3, 4, 5, 6, 1, 7, 4, 2, 3, 0, 7, 1, 6, 7, 3, 6, 4, 0, 1, 2, 5]
# Total Optimal Utility: 759.0
#
# Processing Instance 3 from gap6.txt
# Task Assignments: [0, 2, 7, 4, 6, 0, 2, 4, 4, 4, 7, 0, 6, 4, 3, 5, 7, 1, 2, 0, 5, 6, 3, 7, 1, 5, 6, 3, 5, 3, 1, 1]
# Total Optimal Utility: 758.0
#
# Processing Instance 4 from gap6.txt
# Task Assignments: [3, 2, 6, 3, 7, 1, 7, 0, 1, 5, 1, 6, 4, 5, 4, 6, 2, 3, 1, 2, 7, 3, 0, 7, 5, 1, 3, 5, 0, 2, 0, 4]
# Total Optimal Utility: 752.0
#
# Processing Instance 5 from gap6.txt
# Task Assignments: [2, 7, 7, 0, 2, 5, 7, 7, 0, 6, 3, 1, 6, 6, 7, 2, 5, 0, 5, 5, 2, 3, 1, 4, 6, 4, 3, 6, 3, 4, 3, 1]
# Total Optimal Utility: 747.0
#
# Processing Instance 1 from gap7.txt
# Task Assignments: [6, 1, 4, 6, 4, 4, 3, 2, 5, 4, 2, 5, 0, 5, 4, 1, 2, 1, 3, 7, 7, 6, 1, 7, 2, 3, 0, 1, 2, 5, 0, 5, 6, 7, 3, 1, 5, 2, 7, 0]
# Total Optimal Utility: 942.0
#
# Processing Instance 2 from gap7.txt
# Task Assignments: [4, 4, 1, 7, 2, 7, 0, 0, 7, 1, 0, 5, 6, 1, 1, 7, 6, 4, 7, 0, 5, 6, 3, 1, 7, 3, 2, 6, 4, 5, 4, 2, 2, 5, 6, 5, 0, 3, 7, 3]
# Total Optimal Utility: 949.0
#
# Processing Instance 3 from gap7.txt
# Task Assignments: [0, 4, 1, 2, 3, 3, 4, 4, 5, 6, 7, 3, 2, 0, 3, 4, 1, 7, 0, 6, 5, 0, 2, 7, 0, 6, 2, 0, 1, 4, 5, 6, 6, 1, 7, 2, 5, 6, 3, 2]
# Total Optimal Utility: 968.0
#
# Processing Instance 4 from gap7.txt
# Task Assignments: [7, 1, 4, 3, 4, 2, 0, 7, 4, 7, 5, 3, 6, 2, 3, 5, 6, 1, 0, 1, 5, 4, 6, 2, 2, 5, 1, 0, 2, 6, 5, 3, 7, 0, 1, 3, 1, 7, 2, 2]
# Total Optimal Utility: 945.0
#
# Processing Instance 5 from gap7.txt
# Task Assignments: [2, 7, 0, 0, 7, 5, 1, 7, 6, 1, 4, 4, 3, 3, 7, 4, 7, 4, 5, 1, 5, 3, 6, 7, 2, 2, 0, 2, 1, 5, 3, 0, 4, 6, 1, 3, 4, 0, 6, 0]
# Total Optimal Utility: 951.0
#
# Processing Instance 1 from gap8.txt
# Task Assignments: [0, 0, 7, 3, 5, 5, 2, 5, 3, 6, 1, 7, 1, 6, 0, 5, 3, 2, 3, 5, 4, 1, 7, 1, 0, 4, 6, 7, 6, 4, 2, 1, 3, 6, 1, 5, 7, 5, 4, 4, 2, 0, 7, 0, 2, 2, 4, 2]
# Total Optimal Utility: 1133.0
#
# Processing Instance 2 from gap8.txt
# Task Assignments: [5, 5, 3, 4, 2, 6, 0, 3, 2, 7, 1, 0, 0, 3, 4, 1, 7, 1, 5, 2, 5, 0, 2, 3, 7, 1, 3, 2, 7, 5, 5, 0, 6, 3, 4, 4, 6, 1, 3, 3, 7, 6, 6, 4, 5, 7, 2, 4]
# Total Optimal Utility: 1134.0
#
# Processing Instance 3 from gap8.txt
# Task Assignments: [0, 4, 1, 2, 7, 6, 6, 0, 2, 3, 5, 0, 2, 0, 5, 6, 7, 4, 1, 6, 1, 7, 3, 5, 7, 2, 0, 2, 7, 4, 6, 1, 3, 3, 0, 2, 3, 5, 4, 4, 4, 5, 5, 6, 3, 6, 4, 4]
# Total Optimal Utility: 1141.0
#
# Processing Instance 4 from gap8.txt
# Task Assignments: [4, 5, 6, 3, 0, 3, 0, 3, 7, 7, 4, 5, 1, 2, 2, 6, 6, 4, 0, 4, 6, 5, 6, 1, 6, 4, 7, 4, 4, 1, 0, 6, 3, 7, 2, 7, 1, 6, 0, 3, 1, 0, 7, 2, 5, 1, 3, 2]
# Total Optimal Utility: 1117.0
#
# Processing Instance 5 from gap8.txt
# Task Assignments: [4, 4, 3, 1, 7, 7, 3, 5, 6, 1, 4, 3, 7, 0, 6, 6, 2, 5, 3, 1, 3, 2, 0, 5, 7, 4, 1, 5, 1, 2, 2, 6, 7, 0, 5, 1, 5, 6, 3, 4, 0, 1, 6, 7, 4, 0, 2, 0]
# Total Optimal Utility: 1127.0
#
# Processing Instance 1 from gap9.txt
# Task Assignments: [0, 4, 9, 0, 2, 0, 9, 2, 1, 5, 8, 4, 6, 5, 1, 0, 3, 5, 8, 8, 1, 4, 6, 5, 3, 9, 7, 7, 7, 6]
# Total Optimal Utility: 709.0
#
# Processing Instance 2 from gap9.txt
# Task Assignments: [2, 8, 3, 4, 1, 6, 5, 0, 3, 3, 5, 8, 2, 9, 4, 2, 7, 7, 1, 3, 9, 0, 4, 6, 8, 9, 0, 4, 2, 6]
# Total Optimal Utility: 717.0
#
# Processing Instance 3 from gap9.txt
# Task Assignments: [5, 4, 6, 2, 0, 3, 7, 4, 4, 8, 9, 3, 6, 7, 1, 5, 3, 1, 8, 9, 2, 1, 6, 5, 7, 6, 3, 5, 0, 2]
# Total Optimal Utility: 712.0
#
# Processing Instance 4 from gap9.txt
# Task Assignments: [6, 0, 8, 7, 4, 9, 6, 1, 0, 2, 7, 9, 3, 1, 4, 5, 3, 1, 2, 5, 4, 3, 4, 5, 6, 2, 8, 3, 8, 1]
# Total Optimal Utility: 723.0
#
# Processing Instance 5 from gap9.txt
# Task Assignments: [2, 9, 0, 6, 3, 0, 2, 5, 3, 7, 6, 1, 9, 1, 5, 6, 7, 2, 8, 7, 8, 2, 4, 1, 5, 7, 9, 1, 3, 4]
# Total Optimal Utility: 706.0
#
# Processing Instance 1 from gap10.txt
# Task Assignments: [2, 6, 0, 5, 4, 5, 4, 7, 7, 3, 2, 1, 8, 9, 2, 6, 9, 2, 6, 5, 5, 1, 0, 7, 3, 1, 3, 7, 8, 3, 0, 4, 9, 8, 3, 1, 6, 5, 5, 4]
# Total Optimal Utility: 958.0
#
# Processing Instance 2 from gap10.txt
# Task Assignments: [5, 7, 9, 4, 4, 5, 3, 2, 6, 0, 5, 2, 7, 4, 7, 3, 5, 9, 6, 6, 6, 1, 9, 2, 8, 7, 0, 1, 4, 7, 5, 2, 8, 1, 0, 0, 9, 8, 3, 6]
# Total Optimal Utility: 963.0
#
# Processing Instance 3 from gap10.txt
# Task Assignments: [8, 9, 3, 0, 1, 7, 2, 9, 7, 6, 0, 8, 1, 7, 3, 5, 6, 7, 6, 5, 0, 1, 5, 4, 9, 5, 3, 9, 5, 6, 3, 4, 8, 1, 2, 4, 8, 6, 6, 2]
# Total Optimal Utility: 960.0
#
# Processing Instance 4 from gap10.txt
# Task Assignments: [6, 0, 8, 0, 7, 7, 9, 0, 6, 0, 3, 5, 5, 2, 2, 5, 1, 3, 8, 4, 8, 5, 7, 2, 3, 8, 6, 7, 1, 1, 3, 3, 4, 6, 0, 3, 8, 9, 9, 1]
# Total Optimal Utility: 947.0
#
# Processing Instance 5 from gap10.txt
# Task Assignments: [7, 7, 1, 2, 5, 9, 2, 6, 3, 0, 6, 9, 1, 3, 7, 5, 1, 4, 3, 6, 0, 5, 4, 7, 2, 6, 5, 9, 6, 2, 7, 8, 8, 4, 4, 1, 4, 4, 8, 0]
# Total Optimal Utility: 947.0
#
# Processing Instance 1 from gap11.txt
# Task Assignments: [2, 0, 0, 2, 8, 1, 8, 4, 3, 5, 3, 9, 7, 7, 1, 4, 7, 0, 4, 5, 3, 6, 4, 6, 7, 8, 8, 9, 5, 2, 6, 3, 3, 1, 0, 8, 9, 1, 8, 7, 3, 5, 0, 2, 5, 9, 1, 4, 3, 6]
# Total Optimal Utility: 1139.0
#
# Processing Instance 2 from gap11.txt
# Task Assignments: [0, 5, 1, 3, 1, 3, 3, 6, 2, 9, 5, 1, 9, 1, 5, 7, 2, 2, 0, 5, 3, 4, 0, 7, 6, 4, 8, 8, 0, 8, 7, 8, 3, 4, 9, 9, 0, 3, 4, 9, 6, 5, 0, 2, 4, 7, 9, 2, 8, 7]
# Total Optimal Utility: 1178.0
#
# Processing Instance 3 from gap11.txt
# Task Assignments: [5, 4, 0, 6, 0, 4, 9, 8, 3, 1, 2, 3, 7, 2, 2, 2, 5, 5, 7, 6, 7, 6, 9, 6, 0, 9, 9, 0, 6, 1, 6, 1, 4, 8, 3, 4, 9, 8, 8, 2, 1, 7, 1, 7, 3, 8, 7, 9, 9, 0]
# Total Optimal Utility: 1195.0
#
# Processing Instance 4 from gap11.txt
# Task Assignments: [8, 4, 6, 2, 8, 6, 0, 0, 2, 1, 1, 4, 4, 5, 5, 9, 6, 3, 9, 3, 3, 3, 6, 7, 8, 2, 4, 9, 7, 1, 8, 2, 1, 6, 8, 5, 7, 7, 0, 5, 5, 1, 9, 1, 7, 0, 5, 1, 0, 2]
# Total Optimal Utility: 1171.0
#
# Processing Instance 5 from gap11.txt
# Task Assignments: [7, 0, 2, 7, 3, 9, 0, 1, 6, 9, 1, 4, 3, 6, 0, 1, 0, 0, 9, 8, 0, 6, 7, 6, 7, 6, 7, 5, 4, 3, 9, 1, 4, 0, 2, 9, 3, 8, 4, 2, 4, 3, 3, 5, 5, 2, 2, 7, 5, 8]
# Total Optimal Utility: 1171.0
#
# Processing Instance 1 from gap12.txt
# Task Assignments: [7, 4, 2, 7, 3, 9, 3, 6, 5, 1, 4, 0, 6, 5, 6, 1, 1, 6, 4, 9, 0, 3, 2, 8, 4, 2, 3, 0, 2, 3, 2, 0, 5, 6, 4, 4, 5, 7, 2, 0, 0, 9, 7, 8, 8, 5, 2, 0, 6, 5, 9, 8, 1, 3, 8, 9, 3, 1, 7, 8]
# Total Optimal Utility: 1451.0
#
# Processing Instance 2 from gap12.txt
# Task Assignments: [2, 0, 0, 7, 6, 8, 7, 1, 6, 8, 9, 2, 5, 2, 9, 9, 7, 8, 2, 5, 8, 5, 9, 9, 4, 0, 1, 8, 2, 0, 3, 1, 7, 0, 2, 3, 4, 5, 0, 9, 1, 6, 1, 1, 6, 9, 7, 3, 4, 8, 1, 7, 3, 2, 5, 6, 4, 0, 4, 3]
# Total Optimal Utility: 1449.0
#
# Processing Instance 3 from gap12.txt
# Task Assignments: [6, 1, 9, 3, 4, 3, 3, 4, 7, 7, 5, 8, 2, 8, 0, 4, 9, 2, 2, 7, 5, 5, 9, 9, 4, 7, 0, 2, 8, 1, 0, 5, 0, 6, 8, 9, 4, 1, 3, 3, 2, 7, 6, 9, 6, 3, 1, 6, 8, 5, 7, 0, 0, 8, 1, 5, 4, 1, 0, 2]
# Total Optimal Utility: 1433.0
#
# Processing Instance 4 from gap12.txt
# Task Assignments: [4, 5, 4, 2, 2, 2, 0, 0, 2, 3, 5, 7, 7, 2, 5, 0, 3, 8, 8, 0, 4, 5, 7, 0, 8, 1, 1, 9, 6, 1, 0, 6, 6, 0, 7, 1, 3, 8, 6, 6, 3, 5, 9, 8, 7, 7, 9, 6, 5, 2, 1, 2, 8, 3, 9, 1, 3, 3, 4, 9]
# Total Optimal Utility: 1447.0
#
# Processing Instance 5 from gap12.txt
# Task Assignments: [0, 1, 7, 9, 4, 5, 2, 5, 2, 6, 1, 0, 2, 2, 0, 6, 3, 1, 9, 0, 5, 3, 5, 1, 3, 1, 4, 6, 5, 4, 4, 8, 7, 9, 3, 1, 2, 4, 5, 8, 0, 6, 6, 7, 8, 7, 9, 4, 7, 8, 3, 1, 3, 6, 6, 0, 8, 9, 2, 4]
# Total Optimal Utility: 1446.0
